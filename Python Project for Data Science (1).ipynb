# %% [markdown]
# # Wed Scraping

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests as r

# %%
url='https://en.wikipedia.org/wiki/2023_Indian_Premier_League'

# %%
page =r.get(url)

# %%
soup= BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2023 Indian Premier League - Wikipedia</title>
# ...

# %%
<table class="wikitable sortable jquery-tablesorter">
<thead><tr>
<th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Team
</th>
<th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Stadium
</th>
<th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Location
</th>
<th class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Capacity
</th></tr></thead><tbody>
<tr>
<td><a href="/wiki/Chennai_Super_Kings" title="Chennai Super Kings">Chennai Super Kings</a>
</td>
<td><a href="/wiki/M._A._Chidambaram_Stadium" title="M. A. Chidambaram Stadium">M. A. Chidambaram Stadium</a>
</td>
<td><a href="/wiki/Chennai" title="Chennai">Chennai</a>
</td>
<td>50,000
</td></tr>
<tr>
<td><a href="/wiki/Delhi_Capitals" title="Delhi Capitals">Delhi Capitals</a>
</td>
<td><a href="/wiki/Arun_Jaitley_Stadium" class="mw-redirect" title="Arun Jaitley Stadium">Arun Jaitley Stadium</a>
</td>
<td><a href="/wiki/Delhi" title="Delhi">Delhi</a>
</td>
<td>41,000
</td></tr>
<tr>
<td><a href="/wiki/Gujarat_Titans" title="Gujarat Titans">Gujarat Titans</a>
</td>
<td><a href="/wiki/Narendra_Modi_Stadium" title="Narendra Modi Stadium">Narendra Modi Stadium</a>
</td>
<td><a href="/wiki/Ahmedabad" title="Ahmedabad">Ahmedabad</a>
</td>
<td>132,000
</td></tr>
<tr>
<td><a href="/wiki/Kolkata_Knight_Riders" title="Kolkata Knight Riders">Kolkata Knight Riders</a>
</td>
<td><a href="/wiki/Eden_Gardens" title="Eden Gardens">Eden Gardens</a>
</td>
<td><a href="/wiki/Kolkata" title="Kolkata">Kolkata</a>
</td>
<td>68,000
</td></tr>
<tr>
<td><a href="/wiki/Lucknow_Super_Giants" title="Lucknow Super Giants">Lucknow Super Giants</a>
</td>
<td><a href="/wiki/BRSABV_Ekana_Cricket_Stadium" class="mw-redirect" title="BRSABV Ekana Cricket Stadium">BRSABV Ekana Cricket Stadium</a>
</td>
<td><a href="/wiki/Lucknow" title="Lucknow">Lucknow</a>
</td>
<td>50,000
</td></tr>
<tr>
<td><a href="/wiki/Mumbai_Indians" title="Mumbai Indians">Mumbai Indians</a>
</td>
<td><a href="/wiki/Wankhede_Stadium" title="Wankhede Stadium">Wankhede Stadium</a>
</td>
<td><a href="/wiki/Mumbai" title="Mumbai">Mumbai</a>
</td>
<td>33,000
</td></tr>
<tr>
<td rowspan="2"><a href="/wiki/Punjab_Kings" title="Punjab Kings">Punjab Kings</a>
</td>
<td><a href="/wiki/Himachal_Pradesh_Cricket_Association_Stadium" title="Himachal Pradesh Cricket Association Stadium">Himachal Pradesh Cricket Association Stadium</a>
</td>
<td><a href="/wiki/Dharamshala" title="Dharamshala">Dharamshala</a>
</td>
<td>23,000
</td></tr>
<tr>
<td><a href="/wiki/Inderjit_Singh_Bindra_Stadium" title="Inderjit Singh Bindra Stadium">Inderjit Singh Bindra Stadium</a>
</td>
<td><a href="/wiki/Mohali" title="Mohali">Mohali</a>
</td>
<td>27,000
</td></tr>
<tr>
<td rowspan="2"><a href="/wiki/Rajasthan_Royals" title="Rajasthan Royals">Rajasthan Royals</a>
</td>
<td><a href="/wiki/Assam_Cricket_Association_Stadium,_Guwahati" title="Assam Cricket Association Stadium, Guwahati">Assam Cricket Association Stadium</a>
</td>
<td><a href="/wiki/Guwahati" title="Guwahati">Guwahati</a>
</td>
<td>50,000
</td></tr>
<tr>
<td><a href="/wiki/Sawai_Mansingh_Stadium" title="Sawai Mansingh Stadium">Sawai Mansingh Stadium</a>
</td>
<td><a href="/wiki/Jaipur" title="Jaipur">Jaipur</a>
</td>
<td>30,000
</td></tr>
<tr>
<td><a href="/wiki/Royal_Challengers_Bangalore" title="Royal Challengers Bangalore">Royal Challengers Bangalore</a>
</td>
<td><a href="/wiki/M._Chinnaswamy_Stadium" title="M. Chinnaswamy Stadium">M. Chinnaswamy Stadium</a>
</td>
<td><a href="/wiki/Bengaluru" class="mw-redirect" title="Bengaluru">Bengaluru</a>
</td>
<td>40,000
</td></tr>
<tr>
<td><a href="/wiki/Sunrisers_Hyderabad" title="Sunrisers Hyderabad">Sunrisers Hyderabad</a>
</td>
<td><a href="/wiki/Rajiv_Gandhi_International_Cricket_Stadium" title="Rajiv Gandhi International Cricket Stadium">Rajiv Gandhi International Cricket Stadium</a>
</td>
<td><a href="/wiki/Hyderabad" title="Hyderabad">Hyderabad</a>
</td>
<td>55,000
</td></tr></tbody><tfoot></tfoot></table>
# Out:
#   Cell In[11], line 1
#     <table class="wikitable sortable jquery-tablesorter">
#     ^
# SyntaxError: invalid syntax

# %%
soup.find_all('table')[2]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Team
# </th>
# <th>Stadium
# </th>
# <th>Location
# </th>
# <th>Capacity
# </th></tr>
# <tr>
# <td><a href="/wiki/Chennai_Super_Kings" title="Chennai Super Kings">Chennai Super Kings</a>
# </td>
# <td><a href="/wiki/M._A._Chidambaram_Stadium" title="M. A. Chidambaram Stadium">M. A. Chidambaram Stadium</a>
# </td>
# <td><a href="/wiki/Chennai" title="Chennai">Chennai</a>
# </td>
# <td>50,000
# </td></tr>
# <tr>
# <td><a href="/wiki/Delhi_Capitals" title="Delhi Capitals">Delhi Capitals</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arun_Jaitley_Stadium" title="Arun Jaitley Stadium">Arun Jaitley Stadium</a>
# </td>
# <td><a href="/wiki/Delhi" title="Delhi">Delhi</a>
# </td>
# <td>41,000
# </td></tr>
# <tr>
# <td><a href="/wiki/Gujarat_Titans" title="Gujarat Titans">Gujarat Titans</a>
# </td>
# <td><a href="/wiki/Narendra_Modi_Stadium" title="Narendra Modi Stadium">Narendra Modi Stadium</a>
# </td>
# ...

# %%
table1= soup.find('table', {'class': 'wikitable sortable'})
print(table1)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Team
# </th>
# <th>Stadium
# </th>
# <th>Location
# </th>
# <th>Capacity
# </th></tr>
# <tr>
# <td><a href="/wiki/Chennai_Super_Kings" title="Chennai Super Kings">Chennai Super Kings</a>
# </td>
# <td><a href="/wiki/M._A._Chidambaram_Stadium" title="M. A. Chidambaram Stadium">M. A. Chidambaram Stadium</a>
# </td>
# <td><a href="/wiki/Chennai" title="Chennai">Chennai</a>
# </td>
# <td>50,000
# </td></tr>
# <tr>
# <td><a href="/wiki/Delhi_Capitals" title="Delhi Capitals">Delhi Capitals</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arun_Jaitley_Stadium" title="Arun Jaitley Stadium">Arun Jaitley Stadium</a>
# </td>
# <td><a href="/wiki/Delhi" title="Delhi">Delhi</a>
# </td>
# <td>41,000
# </td></tr>
# <tr>
# <td><a href="/wiki/Gujarat_Titans" title="Gujarat Titans">Gujarat Titans</a>
# </td>
# <td><a href="/wiki/Narendra_Modi_Stadium" title="Narendra Modi Stadium">Narendra Modi Stadium</a>
# </td>
# ...

# %%
headers=table1.find_all("th")
print(headers)
# Out:
# [<th>Team
# </th>, <th>Stadium
# </th>, <th>Location
# </th>, <th>Capacity
# </th>]

# %%
column_content=table1.find_all("tr")
print(column_content)
# Out:
# [<tr>
# <th>Team
# </th>
# <th>Stadium
# </th>
# <th>Location
# </th>
# <th>Capacity
# </th></tr>, <tr>
# <td><a href="/wiki/Chennai_Super_Kings" title="Chennai Super Kings">Chennai Super Kings</a>
# </td>
# <td><a href="/wiki/M._A._Chidambaram_Stadium" title="M. A. Chidambaram Stadium">M. A. Chidambaram Stadium</a>
# </td>
# <td><a href="/wiki/Chennai" title="Chennai">Chennai</a>
# </td>
# <td>50,000
# </td></tr>, <tr>
# <td><a href="/wiki/Delhi_Capitals" title="Delhi Capitals">Delhi Capitals</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arun_Jaitley_Stadium" title="Arun Jaitley Stadium">Arun Jaitley Stadium</a>
# </td>
# <td><a href="/wiki/Delhi" title="Delhi">Delhi</a>
# </td>
# <td>41,000
# </td></tr>, <tr>
# <td><a href="/wiki/Gujarat_Titans" title="Gujarat Titans">Gujarat Titans</a>
# </td>
# <td><a href="/wiki/Narendra_Modi_Stadium" title="Narendra Modi Stadium">Narendra Modi Stadium</a>
# </td>
# <td><a href="/wiki/Ahmedabad" title="Ahmedabad">Ahmedabad</a>
# </td>
# ...

# %%
main_columns = [title.text.strip() for title in headers]
print(main_columns)
# Out:
# ['Team', 'Stadium', 'Location', 'Capacity']

# %%
import pandas as pd
import numpy as np

# %%
data1= pd.DataFrame(columns=main_columns)
df.reset_index(drop=True) 
data1
# Out:
# Empty DataFrame
# Columns: [Team, Stadium, Location, Capacity]
# Index: []

# %%
for row in column_content[1:]:
    row_data=row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
# Out:
# ['Chennai Super Kings', 'M. A. Chidambaram Stadium', 'Chennai', '50,000']
# ['Delhi Capitals', 'Arun Jaitley Stadium', 'Delhi', '41,000']
# ['Gujarat Titans', 'Narendra Modi Stadium', 'Ahmedabad', '132,000']
# ['Kolkata Knight Riders', 'Eden Gardens', 'Kolkata', '68,000']
# ['Lucknow Super Giants', 'BRSABV Ekana Cricket Stadium', 'Lucknow', '50,000']
# ['Mumbai Indians', 'Wankhede Stadium', 'Mumbai', '33,000']
# ['Punjab Kings', 'Himachal Pradesh Cricket Association Stadium', 'Dharamshala', '23,000']
# ['Inderjit Singh Bindra Stadium', 'Mohali', '27,000']
# ['Rajasthan Royals', 'Assam Cricket Association Stadium', 'Guwahati', '50,000']
# ['Sawai Mansingh Stadium', 'Jaipur', '30,000']
# ['Royal Challengers Bangalore', 'M. Chinnaswamy Stadium', 'Bengaluru', '40,000']
# ['Sunrisers Hyderabad', 'Rajiv Gandhi International Cricket Stadium', 'Hyderabad', '55,000']

# %%
output_list = []
for row in column_content[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    output_list.append(individual_row_data)

# Convert the list to a DataFrame
df = pd.DataFrame(output_list)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                                 0  \
# 0             Chennai Super Kings
# 1                  Delhi Capitals
# 2                  Gujarat Titans
# 3           Kolkata Knight Riders
# 4            Lucknow Super Giants
# 5                  Mumbai Indians
# 6                    Punjab Kings
# 7   Inderjit Singh Bindra Stadium
# 8                Rajasthan Royals
# 9          Sawai Mansingh Stadium
# 10    Royal Challengers Bangalore
# 11            Sunrisers Hyderabad
#
#                                                1            2        3
# 0                      M. A. Chidambaram Stadium      Chennai   50,000
# 1                           Arun Jaitley Stadium        Delhi   41,000
# 2                          Narendra Modi Stadium    Ahmedabad  132,000
# 3                                   Eden Gardens      Kolkata   68,000
# 4                   BRSABV Ekana Cricket Stadium      Lucknow   50,000
# 5                               Wankhede Stadium       Mumbai   33,000
# ...

# %%
df = df.rename(columns={0:'Team',1:'Stadium',2:'Location',3:'capacity'})

# %%
df.to_csv('web_scraping.csv',index=False)

# %%
df.dropna()
# Out:
#                            Team                                       Stadium  \
# 0           Chennai Super Kings                     M. A. Chidambaram Stadium
# 1                Delhi Capitals                          Arun Jaitley Stadium
# 2                Gujarat Titans                         Narendra Modi Stadium
# 3         Kolkata Knight Riders                                  Eden Gardens
# 4          Lucknow Super Giants                  BRSABV Ekana Cricket Stadium
# 5                Mumbai Indians                              Wankhede Stadium
# 6                  Punjab Kings  Himachal Pradesh Cricket Association Stadium
# 8              Rajasthan Royals             Assam Cricket Association Stadium
# 10  Royal Challengers Bangalore                        M. Chinnaswamy Stadium
# 11          Sunrisers Hyderabad    Rajiv Gandhi International Cricket Stadium
#
#        Location capacity
# 0       Chennai   50,000
# 1         Delhi   41,000
# 2     Ahmedabad  132,000
# ...

# %%
df.shape
# Out:
# (12, 4)

# %%
df.size
# Out:
# 48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Team      12 non-null     object
#  1   Stadium   12 non-null     object
#  2   Location  12 non-null     object
#  3   capacity  10 non-null     object
# dtypes: object(4)
# memory usage: 516.0+ bytes

# %%
df.memory_usage()
# Out:
# Index       132
# Team         96
# Stadium      96
# Location     96
# capacity     96
# dtype: int64

# %%
df.head(2)
# Out:
#                   Team                    Stadium Location capacity
# 0  Chennai Super Kings  M. A. Chidambaram Stadium  Chennai   50,000
# 1       Delhi Capitals       Arun Jaitley Stadium    Delhi   41,000

# %%
df.dtypes
# Out:
# Team        object
# Stadium     object
# Location    object
# capacity    object
# dtype: object
